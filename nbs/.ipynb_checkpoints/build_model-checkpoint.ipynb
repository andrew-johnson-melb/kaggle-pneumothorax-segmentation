# %% [markdown]
# # Pneumothorax segmentation

# %%
#! git remote add origin https://github.com/andrew-johnson-melb/kaggle-pneumothorax-segmentation.git

# %%
#!pip install albumentations
SRC_FILES = '/home/ec2-user/SageMaker/seg_project/src'

# %%
import os
import sys
import torch
import gc
from tqdm import tqdm
import cv2
from glob import glob
from collections import namedtuple
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils import clip_grad_norm_
from torch.utils.data import WeightedRandomSampler

sys.path.append(SRC_FILES)

from utils import *
from unet import UNet
from transforms import get_transforms
from trainer import train_one_epoch, evaluate
from dataset import PneumothoraxDataset
from vis import show_batch, compare_masks
from loss import MixedLoss, dice_loss, dice_metric

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
LABELLED_DATA = '/home/ec2-user/SageMaker/seg_project/data/preprocessed_data/train/size-512/'
LABELS_MASKS = '/home/ec2-user/SageMaker/seg_project/data/preprocessed_data/train-masks/size-512/'
TEST_DATA = '/home/ec2-user/SageMaker/seg_project/data/preprocessed_data/test/size-512/'
META_DATA_DIR = '/home/ec2-user/SageMaker/seg_project/data/meta_data_siim.csv'

# %% [markdown]
# ## Constructing training and testing sets

# %% [markdown]
# Load the meta data which contains file names, labels, and patient info
# then split the dataframe into the labelled data (for development) and the test data used for Kaggles validation.

# %%
meta_data_df = pd.read_csv(META_DATA_DIR, index_col=0)
labelled_df_set = meta_data_df[meta_data_df.train_set]
test_df_set = meta_data_df[~meta_data_df.train_set]

# %% [markdown]
# Add the full paths to the masks and images, these paths
# will be used by the dataloader to read the file from disk

# %%
test_df_set['images'] = TEST_DATA + test_df_set.file_name + '.png'
labelled_df_set['images'] = LABELLED_DATA + labelled_df_set.file_name + '.png'
labelled_df_set['masks'] = LABELS_MASKS + labelled_df_set.file_name + '.png'
labelled_df_set.head(2)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    PatientAge                             PatientID PatientSex  \
# 0          38  17d405a3-a0d2-4901-b33a-63906aa48d9f          M
# 1          10  8ab1ffda-8b65-4914-95d6-2e549e328666          F
#
#    PatientOrientation ViewPosition      label  train_set  \
# 0                 NaN           PA  no-region       True
# 1                 NaN           AP  no-region       True
#
#                                            file_name  \
# 0  1.2.276.0.7230010.3.1.4.8323329.1000.151787516...
# 1  1.2.276.0.7230010.3.1.4.8323329.10000.15178752...
#
#                                               images  \
# 0  /home/ec2-user/SageMaker/seg_project/data/prep...
# 1  /home/ec2-user/SageMaker/seg_project/data/prep...
#
#                                                masks
# 0  /home/ec2-user/SageMaker/seg_project/data/prep...
# 1  /home/ec2-user/SageMaker/seg_project/data/prep...

# %% [markdown]
# Split the data randomly into a train and test set.
# Cross validation could be used here to get a more
# accurate measure of the generalisation of the model but for speed of development we will use a simple random split.

# %%
train_set_df, val_set_df = train_dev_split(labelled_df_set)

# %% [markdown]
# ## Create dataloaders

# %%
# Create dataset for the training and validation data
aug_training, aug_validation = get_transforms()
train_dataset = PneumothoraxDataset(files_df=train_set_df, labelled=True, transform=aug_training)
val_dataset = PneumothoraxDataset(files_df=val_set_df, labelled=True, transform=aug_validation)

# %%
Configs = namedtuple('TrainingConfigs', ['batch_size', 'ratio_pos_neg_sample', 'lr', 'num_epochs'])
configs = Configs(batch_size=8, ratio_pos_neg_sample=5, lr=0.00005, num_epochs=40)

# %% [markdown]
# ## Dealing with Class imbalance
#
# Only 20% of the samples contain the positive class label (indicating Pneumothorax)
# This imbalance will cause issues when training the model: the model is only
# predicting zero for the entire region. To counter this we can increase the
# frequency at which the positive samples are drawn. We do this using
# the pytorch WeightedRandomSampler. We will use the labels contained
# in the meta data to construct a vector of weights which the WeightedRandomSampler
# will use to sample the data.

# %%
train_set_df = gen_upsampling_weights(train_set_df, ratio_pos_neg=configs.ratio_pos_neg_sample)
weighted_sampler = WeightedRandomSampler(weights=train_set_df.weights.values, num_samples=train_set_df.shape[0])
# Out:
# Number of negative examples = 7542
# Number of positive examples = 2129
# Fraction Neg Examples (raw data) = 0.7799
# Upsampling amount = 17.7

# %%
train_dataloader = DataLoader(dataset=train_dataset, batch_size=configs.batch_size, num_workers=6, sampler=weighted_sampler)
val_dataloader = DataLoader(dataset=val_dataset, batch_size=8, num_workers=6, shuffle=False)

# %%
# It can be very helpful to inspect the transformed data and (normalization aside) exactly the data
# that is going into training the model. 

_ = show_batch(train_dataloader)

# %% [markdown]
# # Building Unet-like Model and Dice loss

# %%
# Get some sample data
input_, target = get_sample(train_dataloader)

# Create model
unet = UNet()
output = unet(input_)
output = output.squeeze()

print(f'Input Shape  = {input_.shape}')
print(f'Target (y) shape = {target.shape}')
print(f"Output shape = {output.shape}")
# Out:
# Input Shape  = torch.Size([8, 3, 512, 512])
# Target (y) shape = torch.Size([8, 512, 512])
# Output shape = torch.Size([8, 512, 512])

# %%
# Lets have a quick look at the model prediction and the mask values.
for i in range(1):
    im, t = output[i], target[i]
    print(f'Best Dice = {dice_loss(im.float(), t.float())}')
    print(f'Best Dice = {dice_metric(im.float(), t.float())}')
    print(f'Best BCE = {bce_loss(im.float(), t.float())}')
    compare_masks(im,t, label=i)
# Out:
# Best Dice = 1.0
# Best Dice = 8.045730304218068e-09
# Best BCE = 0.6426959037780762

# %%
# Check the sizes 
print_model_sizes(unet, input_)
# Out:
# Input size = torch.Size([8, 3, 512, 512])
# Layer = 0 (encoder) Shape Out = torch.Size([8, 512, 16, 16])
# Layer = 1 (pool) Shape Out = torch.Size([8, 512, 8, 8])
# Layer = 2 (center_layer) Shape Out = torch.Size([8, 256, 16, 16])
# Layer = 3 (up_block_1) Shape Out = torch.Size([8, 256, 32, 32])
# Layer = 4 (up_block_2) Shape Out = torch.Size([8, 256, 64, 64])
# Layer = 5 (up_block_3) Shape Out = torch.Size([8, 64, 128, 128])
# Layer = 6 (up_block_4) Shape Out = torch.Size([8, 128, 256, 256])
# Layer = 7 (up_block_5) Shape Out = torch.Size([8, 32, 512, 512])
# Layer = 8 (block_5_conv1) Shape Out = torch.Size([8, 32, 512, 512])
# Layer = 9 (block_5_conv2) Shape Out = torch.Size([8, 1, 512, 512])

# %% [markdown]
# # Train the segmentation model

# %%
    for loss_name in eval_losses.keys():
        batch_losses[loss_name] = []

    for images, targets in data_loader:
        images, targets = images.to(device), targets.to(device)
        outputs = model(images)
        outputs = outputs.squeeze()
        # Compute the loss for each loss attached to
        # the dict eval_losses
        for loss_name, loss_fn in eval_losses.items():
            batch_losses[loss_name].append(loss_fn(outputs, targets).item())

    # Compute the epoch-level averages
    for loss_name in eval_losses.keys():
        epoch_loss = np.array(batch_losses[loss_name]).mean()
        print(f'\t Validation loss: {loss_name}={epoch_loss}')

# %%
class MetricCollector:
    """Class to store and calculate loss metrics
    
    This is a terrible class, the entire training loop should be a class
    which would make this eaiser. But time is of the essense.
    
    params:
        eval_losses (dict): dict contained loss metric name and function
        
    """
    
    def __init__(self, eval_losses):
        
        self.eval_losses = eval_losses
        self.batch_losses, self.epoch_losses = {}, {}
        self.create_and_reset_lists()

    def batch_loss(self, outputs, targets):
        # Compute the loss metrics on the input batch.
        # All of the metrics stored in eval_losses are computed
        for loss_name, loss_fn in eval_losses.items():
            self.batch_losses[loss_name].append(loss_fn(outputs, targets).item())
    
    def epoch_loss(self, epoch_num):
        # At the end of an epoch we can aggregrate all of the batch level losses
        for loss_name in eval_losses.keys():
            epoch_loss = np.array(self.batch_losses[loss_name]).mean()
            print(f'\t Validation loss (epoch = {epoch_num}): {loss_name}={epoch_loss}')
        # Once the epoch level stats are computed we can reset the list 
        # of batch losses
        self._reset_list()
        
    def create_and_reset_lists(self, reset_epoch=False):
        # At the end of an epoch we need to remove all the stored
        # batch loss values
        for loss_name in eval_losses.keys():
            self.batch_losses[loss_name] = []
            self.epoch_losses[loss_name] = []
# Out:
# TrainingConfigs(batch_size=8, ratio_pos_neg_sample=5, lr=5e-05, num_epochs=40)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
num_epochs = configs.num_epochs

model = UNet(freeze_encoder=False)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(),lr=configs.lr)

# Create a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

# Standard BCE loss
loss_fn = MixedLoss(10.0,2.0)
validation_losses = {'dice_loss' : dice_loss, 'mixed loss': loss_fn, 'dice_metric': dice_metric}

# %%
print('Random model loss training')
evaluate(model, train_dataloader, device, validation_losses, epoch=-1)
# Out:
# Random model loss training
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# 	 Validation loss: dice_loss=0.9756835327476525
# 	 Validation loss: mixed loss=3.857487350990914
# 	 Validation loss: dice_metric=0.0243164672523476

# %%
print('Random model loss validation')
evaluate(model, val_dataloader, device, validation_losses, epoch=-1)
# Out:
# Random model loss validation
# 	 Validation loss: dice_loss=0.9938945426573071
# 	 Validation loss: mixed loss=7.262554511214954
# 	 Validation loss: dice_metric=0.0061054573426927205

# %%
for epoch_idx in range(5):
    train_one_epoch(model, optimizer, loss_fn, train_dataloader, device , epoch_idx)
    lr_scheduler.step()
    evaluate(model, val_dataloader, device, validation_losses, epoch_idx)
# Out:
# Epoch=0
# 	 Training loss = 1.663707796054182
# 	 Validation loss: dice_loss=0.3117779275660706
# 	 Validation loss: mixed loss=3.2533879527806344
# 	 Validation loss: dice_metric=0.6882220724339293
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-4c1b1611c26e> in <module>
#       1 for epoch_idx in range(5):
# ----> 2     train_one_epoch(model, optimizer, loss_fn, train_dataloader, device , epoch_idx)
#       3     lr_scheduler.step()
#       4     evaluate(model, val_dataloader, device, validation_losses, epoch_idx)
#
# ~/SageMaker/seg_project/src/trainer.py in train_one_epoch(model, optimizer, loss_fn, data_loader, device, epoch)
#       7     model.train()
#       8     batch_losses = []
# ----> 9     for batch_ix, (images, targets) in enumerate(data_loader):
#      10         # Put the batch on the gpu
#      11         images, targets = images.to(device), targets.to(device)
#
# KeyboardInterrupt:
